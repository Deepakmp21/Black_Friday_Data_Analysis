# %%
import pandas as pd

# %%
df = pd.read_csv("BlackFriday.csv")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %% [markdown]
# ## File2(BlackFriday - Analysing Columns)

# %%
df['User_ID']
# Out:
# 0         1000001
# 1         1000001
# 2         1000001
# 3         1000001
# 4         1000002
#            ...
# 537572    1004737
# 537573    1004737
# 537574    1004737
# 537575    1004737
# 537576    1004737
# Name: User_ID, Length: 537577, dtype: int64

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['City_Category'].nunique()
# Out:
# 3

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df['Product_Category_1'].nunique()
# Out:
# 18

# %%
df['Purchase'].nunique()
# Out:
# 17959

# %%
df['Purchase'].sum()
# Out:
# 5017668378

# %%
df['Purchase'].sum()/len(df['Purchase'])
# Out:
# 9333.859852635065

# %%
for column in df.columns:
    print(column,":",df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %% [markdown]
# ## File3(BlackFriday- Analyzing Gender)

# %%
len(df[df['Gender']== 'M']),len(df[df['Gender']== 'F'])
# Out:
# (405380, 132197)

# %%
data = pd.DataFrame({'Ratio' : [len(df[df['Gender']=='M']) , len(df[df['Gender']== 'F'])]} 
                    , index = ['Male' , 'Female'])

# %%
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
data.plot.pie(y= 'Ratio')
# Out:
# <AxesSubplot:ylabel='Ratio'>

# %%
data.plot.pie(y = 'Ratio' , figsize = (3,5))
# Out:
# <AxesSubplot:ylabel='Ratio'>

# %%
data.plot.pie(y= 'Ratio' , figsize =(4,5) , autopct = "%.2f" )
# Out:
# <AxesSubplot:ylabel='Ratio'>

# %%
df.groupby('Gender').size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
df.groupby('Gender').size().plot(kind = 'pie' 
                                , autopct = "%.2f"
                                , title = 'Gender Ratio' 
                                , figsize = (3,5))
# Out:
# <AxesSubplot:title={'center':'Gender Ratio'}, ylabel='None'>

# %%
df.groupby('Gender').size().plot(kind = 'bar' 
                                , title = 'Gender Ratio' 
                                , figsize = (3,5))
# Out:
# <AxesSubplot:title={'center':'Gender Ratio'}, xlabel='Gender'>

# %%
df.groupby('Gender').size().plot(kind = 'bar'  
                                , figsize = (3,5))
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind= 'pie'
                                           ,autopct ="%.2f")
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind= 'pie'
                                            , title = 'Purchase Ratio'
                                           ,autopct ="%.2f")
# Out:
# <AxesSubplot:title={'center':'Purchase Ratio'}, ylabel='Purchase'>

# %%
df.groupby('Gender').mean()['Purchase'].plot(kind= 'pie'
                                            , title = 'Purchase Ratio'
                                           ,autopct ="%.2f")
# Out:
# <AxesSubplot:title={'center':'Purchase Ratio'}, ylabel='Purchase'>

# %% [markdown]
# ## File4(Analysing Age & Marital Status

# %%
df.groupby('Age').size().plot(kind='bar', figsize = (12,6) , title ="Purshase Distribution by Age" )
# Out:
# <AxesSubplot:title={'center':'Purshase Distribution by Age'}, xlabel='Age'>

# %%
for i in df['Age'].unique():
    print(i)
# Out:
# 0-17
# 55+
# 26-35
# 46-50
# 51-55
# 36-45
# 18-25

# %%
df[df['Age'] == '0-17']
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  0-17          10             A
# 1       1000001  P00248942      F  0-17          10             A
# 2       1000001  P00087842      F  0-17          10             A
# 3       1000001  P00085442      F  0-17          10             A
# 85      1000019  P00112542      M  0-17          10             A
# ...         ...        ...    ...   ...         ...           ...
# 537280  1004690  P00242742      F  0-17          10             C
# 537281  1004690  P00226442      F  0-17          10             C
# 537282  1004690  P00181442      F  0-17          10             C
# 537283  1004690  P00192042      F  0-17          10             C
# 537354  1004707  P00253042      M  0-17           0             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
len(df[df['Age'] == '0-17'])
# Out:
# 14707

# %%
len(df[df['Age'] == '26-35'])
# Out:
# 214690

# %%
for i in df['Age'].unique():
    print( len(df[df['Age'] == i]))
# Out:
# 14707
# 20903
# 214690
# 44526
# 37618
# 107499
# 97634

# %%
for i in df['Age'].unique():
    print(i," : " ,len(df[df['Age'] == i]))
# Out:
# 0-17  :  14707
# 55+  :  20903
# 26-35  :  214690
# 46-50  :  44526
# 51-55  :  37618
# 36-45  :  107499
# 18-25  :  97634

# %%
df[df['Age'] == i]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 70      1000018  P00366542      F  18-25           3             B
# 71      1000018  P00190742      F  18-25           3             B
# 72      1000018  P00151842      F  18-25           3             B
# 73      1000018  P00112642      F  18-25           3             B
# 74      1000018  P00118442      F  18-25           3             B
# ...         ...        ...    ...    ...         ...           ...
# 537566  1004736  P00048742      M  18-25          20             A
# 537567  1004736  P00157542      M  18-25          20             A
# 537568  1004736  P00250642      M  18-25          20             A
# 537569  1004736  P00023142      M  18-25          20             A
# 537570  1004736  P00162442      M  18-25          20             A
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 70                              3               0                   5
# ...

# %%
i
# Out:
# '18-25'

# %%
df[df['Age'] == i]['Product_ID']
# Out:
# 70        P00366542
# 71        P00190742
# 72        P00151842
# 73        P00112642
# 74        P00118442
#             ...
# 537566    P00048742
# 537567    P00157542
# 537568    P00250642
# 537569    P00023142
# 537570    P00162442
# Name: Product_ID, Length: 97634, dtype: object

# %%
df[df['Age'] == i]['Product_ID'].nunique()
# Out:
# 3213

# %%
lst =[]
for i in df['Age'].unique():
    lst.append([i ,df[df['Age'] == i] ['Product_ID'].nunique()])
data = pd.DataFrame(lst , columns = ['Age','Products'])

# %%
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
data.plot.bar(x= 'Age',figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df.groupby('Age').sum().plot(kind='bar', figsize = (12,6) , title ="Amount spend by Age" )
# Out:
# <AxesSubplot:title={'center':'Amount spend by Age'}, xlabel='Age'>

# %%
df.groupby('Age').sum()['Purchase'].plot(kind='bar', figsize = (12,6) , title ="Amount spend by Age" )
# Out:
# <AxesSubplot:title={'center':'Amount spend by Age'}, xlabel='Age'>

# %%
df.groupby('Age').mean()['Purchase'].plot(kind='bar', figsize = (12,6) , title ="Amount spend by Age" )
# Out:
# <AxesSubplot:title={'center':'Amount spend by Age'}, xlabel='Age'>

# %%
df.groupby('Age').mean()['Purchase']
# Out:
# Age
# 0-17     9020.126878
# 18-25    9235.197575
# 26-35    9314.588970
# 36-45    9401.478758
# 46-50    9284.872277
# 51-55    9620.616620
# 55+      9453.898579
# Name: Purchase, dtype: float64

# %%
df.groupby('Age').mean()['Purchase'].plot(kind='pie',autopct="%.2f",title ="Amout spend by Age")
# Out:
# <AxesSubplot:title={'center':'Amout spend by Age'}, ylabel='Purchase'>

# %%
df.groupby('Marital_Status').size().plot(kind='pie', autopct="%0.2f")
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.groupby('Gender').size().plot(kind='pie', autopct="%0.2f")
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# ## File5(BlackFriday- Multi Column Analysis)

# %%
import pandas as pd
import seaborn as sns

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot( x = "Age" , hue = "Gender" , data = df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot( x = "Gender" , hue = "Age" , data = df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot( x = "Gender" , hue = "Marital_Status" , data = df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot( x = "Marital_Status" , hue = "Gender" , data = df)
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x= df['City_Category'])
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').size().plot(kind= 'pie' , autopct ='%0.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
sns.countplot(x= df['City_Category'] , hue= 'Age' , data=df)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x= 'Age' , hue= 'City_Category' , data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x= 'Marital_Status' , hue= 'City_Category' , data=df)
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x= 'City_Category' , hue= 'Gender' , data=df)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
df.groupby('City_Category').sum()['Purchase']
# Out:
# City_Category
# A    1295668797
# B    2083431612
# C    1638567969
# Name: Purchase, dtype: int64

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind ='pie' , autopct ="%0.2f")
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %%
df.groupby('City_Category').mean()['Purchase'].plot(kind ='pie' , autopct ="%0.2f")
# Out:
# <AxesSubplot:ylabel='Purchase'>

# %% [markdown]
# ## Files6(BlackFriday - Occupation and Product Analysis)

# %%
sns.countplot(x= df['Stay_In_Current_City_Years'])
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x= 'Stay_In_Current_City_Years' , hue= 'Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x= 'Gender' , hue= 'Stay_In_Current_City_Years', data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x= 'Stay_In_Current_City_Years' , hue= 'Marital_Status', data=df)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x= 'Stay_In_Current_City_Years' , hue= 'City_Category', data=df)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x= 'City_Category' , data =df)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
sns.countplot( x= 'City_Category' ,
              hue ='Age', data=df)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').size()
# Out:
# Stay_In_Current_City_Years
# 0      72725
# 1     189192
# 2      99459
# 3      93312
# 4+     82889
# dtype: int64

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind = 'pie' ,autopct="%0.2f")
# Out:
# <AxesSubplot:ylabel='None'>
